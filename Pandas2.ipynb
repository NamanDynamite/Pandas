# %%
import pandas as pd

# %%
pd.read_csv("A:\\Data Science\\student_results.csv")
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 0        1001     10          2             9                       3  \
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
pd.read_csv("A:\\Data Science\\Top-10-IT-Companies-in-India.csv")
# Out:
#   Top 10 IT Companies in India
# 0                          TCS
# 1                      Infosys
# 2                Tech Mahindra
# 3                        Wipro
# 4             HCL Technologies
# 5                 L&T Infotech
# 6                     Mindtree
# 7                      Mphasis
# 8    Oracle Financial Services
# 9                  Rotla India

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Naman\Desktop\jupyter notebook\Data science\Pandas

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Name', 'Industry', 'Inception', 'Revenue', 'Expenses',
#        'Profit', 'Growth'],
#       dtype='object')

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", nrows = 5)
df
# Out:
#    ID Date             Name            Industry  Inception       Revenue
# 0   1  yes          Lamtone         IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind  Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation              Health       2012  $10,597,009
# 3   4   no         Mattouch         IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                 NaN       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# 4  7,435,363 Dollars   3138627     8%

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", usecols = [2])
df
# Out:
#               Name
# 0          Lamtone
# 1        Stripfind
# 2  Canecorporation
# 3         Mattouch
# 4        Techdrill
# 5         Techline
# 6          Cityace
# 7   Kayelectronics
# 8          Ganzlax
# 9      Trantraxlax

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", index_col = 2 )
df
# Out:
#                  ID Date             Industry  Inception       Revenue
# Name
# Lamtone           1  yes          IT Services       2009  $11,757,018   \
# Stripfind         2   no   Financial Services       2010  $12,329,371
# Canecorporation   3  yes               Health       2012  $10,597,009
# Mattouch          4   no          IT Services       2013  $14,026,934
# Techdrill         5  yes                  NaN       2009  $10,573,990
# Techline          6   no               Health       2006  $13,898,119
# Cityace           7  yes               Health       2010   $9,254,614
# Kayelectronics    8   no               Health       2009   $9,451,943
# Ganzlax           9  yes                  NaN       2011  $14,001,180
# Trantraxlax      10   no  Government Services       2011           NaN
#
#                           Expenses    Profit Growth
# Name
# Lamtone          6,482,465 Dollars   5274553    30%
# Stripfind          916,455 Dollars  11412916    20%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", header = 1)
df
# Out:
#     1  yes          Lamtone          IT Services  2009  $11,757,018
# 0   2   no        Stripfind   Financial Services  2010  $12,329,371   \
# 1   3  yes  Canecorporation               Health  2012  $10,597,009
# 2   4   no         Mattouch          IT Services  2013  $14,026,934
# 3   5  yes        Techdrill                  NaN  2009  $10,573,990
# 4   6   no         Techline               Health  2006  $13,898,119
# 5   7  yes          Cityace               Health  2010   $9,254,614
# 6   8   no   Kayelectronics               Health  2009   $9,451,943
# 7   9  yes          Ganzlax                  NaN  2011  $14,001,180
# 8  10   no      Trantraxlax  Government Services  2011           NaN
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  NaN
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", names = ["a","b","c","d","e","f","g","h"])
df
# Out:
#        a                b                    c          d             e
# ID  Date             Name             Industry  Inception       Revenue  \
# 1    yes          Lamtone          IT Services       2009  $11,757,018
# 2     no        Stripfind   Financial Services       2010  $12,329,371
# 3    yes  Canecorporation               Health       2012  $10,597,009
# 4     no         Mattouch          IT Services       2013  $14,026,934
# 5    yes        Techdrill                  NaN       2009  $10,573,990
# 6     no         Techline               Health       2006  $13,898,119
# 7    yes          Cityace               Health       2010   $9,254,614
# 8     no   Kayelectronics               Health       2009   $9,451,943
# 9    yes          Ganzlax                  NaN       2011  $14,001,180
# 10    no      Trantraxlax  Government Services       2011           NaN
#
#                     f         g       h
# ID           Expenses    Profit  Growth
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.head(11)
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.tail()
# Out:
#    ID Date            Name             Industry  Inception       Revenue
# 5   6   no        Techline               Health       2006  $13,898,119   \
# 6   7  yes         Cityace               Health       2010   $9,254,614
# 7   8   no  Kayelectronics               Health       2009   $9,451,943
# 8   9  yes         Ganzlax                  NaN       2011  $14,001,180
# 9  10   no     Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", dtype = {"ID": "float64"})
df
# Out:
#      ID Date             Name             Industry  Inception       Revenue
# 0   1.0  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2.0   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  yes  Canecorporation               Health       2012  $10,597,009
# 3   4.0   no         Mattouch          IT Services       2013  $14,026,934
# 4   5.0  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6.0   no         Techline               Health       2006  $13,898,119
# 6   7.0  yes          Cityace               Health       2010   $9,254,614
# 7   8.0   no   Kayelectronics               Health       2009   $9,451,943
# 8   9.0  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10.0   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", dtype = {"ID": "float64","Profit":"float64"})
df
# Out:
#      ID Date             Name             Industry  Inception       Revenue
# 0   1.0  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2.0   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  yes  Canecorporation               Health       2012  $10,597,009
# 3   4.0   no         Mattouch          IT Services       2013  $14,026,934
# 4   5.0  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6.0   no         Techline               Health       2006  $13,898,119
# 6   7.0  yes          Cityace               Health       2010   $9,254,614
# 7   8.0   no   Kayelectronics               Health       2009   $9,451,943
# 8   9.0  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10.0   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv",true_values = ["yes"],false_values = ["no"])
df
# Out:
#    ID   Date             Name             Industry  Inception       Revenue
# 0   1   True          Lamtone          IT Services       2009  $11,757,018   \
# 1   2  False        Stripfind   Financial Services       2010  $12,329,371
# 2   3   True  Canecorporation               Health       2012  $10,597,009
# 3   4  False         Mattouch          IT Services       2013  $14,026,934
# 4   5   True        Techdrill                  NaN       2009  $10,573,990
# 5   6  False         Techline               Health       2006  $13,898,119
# 6   7   True          Cityace               Health       2010   $9,254,614
# 7   8  False   Kayelectronics               Health       2009   $9,451,943
# 8   9   True          Ganzlax                  NaN       2011  $14,001,180
# 9  10  False      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", na_values = ["not available","no values"])
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", na_values = {"Industry":"no values","Growth":"not available"})
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", keep_default_na = False)
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                            2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                            2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv", na_filter = False)
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                            2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                            2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.isnull().sum().sum()
# Out:
# 5

# %%
df.notnull()
# Out:
#      ID  Date  Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  True  True  True      True       True     True      True    True    True
# 1  True  True  True      True       True     True      True    True    True
# 2  True  True  True      True       True     True      True    True    True
# 3  True  True  True      True       True     True      True    True   False
# 4  True  True  True     False       True     True      True    True    True
# 5  True  True  True      True       True     True      True    True    True
# 6  True  True  True      True       True     True      True    True    True
# 7  True  True  True      True       True     True      True    True    True
# 8  True  True  True     False       True     True     False    True    True
# 9  True  True  True      True       True    False      True    True    True

# %%
df.notnull().sum().sum()
# Out:
# 85

# %%
import numpy as np

# %%
na = pd.Series([1,2,3,np.nan])
na
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
na.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
na.isnull().sum()
# Out:
# 1

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.dropna(axis =0)
# Out:
#    ID Date             Name            Industry  Inception       Revenue
# 0   1  yes          Lamtone         IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind  Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation              Health       2012  $10,597,009
# 5   6   no         Techline              Health       2006  $13,898,119
# 6   7  yes          Cityace              Health       2010   $9,254,614
# 7   8   no   Kayelectronics              Health       2009   $9,451,943
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%

# %%
df.dropna(axis =1,how =  "any")
# Out:
#    ID Date             Name  Inception    Profit
# 0   1  yes          Lamtone       2009   5274553
# 1   2   no        Stripfind       2010  11412916
# 2   3  yes  Canecorporation       2012   3005820
# 3   4   no         Mattouch       2013   6597557
# 4   5  yes        Techdrill       2009   3138627
# 5   6   no         Techline       2006   8427816
# 6   7  yes          Cityace       2010   3005116
# 7   8   no   Kayelectronics       2009   5573830
# 8   9  yes          Ganzlax       2011  11901180
# 9  10   no      Trantraxlax       2011   5453060

# %%
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.dropna(thresh = 9)
# Out:
#    ID Date             Name            Industry  Inception       Revenue
# 0   1  yes          Lamtone         IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind  Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation              Health       2012  $10,597,009
# 5   6   no         Techline              Health       2006  $13,898,119
# 6   7  yes          Cityace              Health       2010   $9,254,614
# 7   8   no   Kayelectronics              Health       2009   $9,451,943
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%

# %%
df.dropna(subset = ["Industry"])
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.dropna()
# Out:
#    ID Date             Name            Industry  Inception       Revenue
# 0   1  yes          Lamtone         IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind  Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation              Health       2012  $10,597,009
# 5   6   no         Techline              Health       2006  $13,898,119
# 6   7  yes          Cityace              Health       2010   $9,254,614
# 7   8   no   Kayelectronics              Health       2009   $9,451,943
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%

# %%
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.dropna(inplace = True)
df
# Out:
#    ID Date             Name            Industry  Inception       Revenue
# 0   1  yes          Lamtone         IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind  Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation              Health       2012  $10,597,009
# 5   6   no         Techline              Health       2006  $13,898,119
# 6   7  yes          Cityace              Health       2010   $9,254,614
# 7   8   no   Kayelectronics              Health       2009   $9,451,943
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%

# %%
df
# Out:
#    ID Date             Name            Industry  Inception       Revenue
# 0   1  yes          Lamtone         IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind  Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation              Health       2012  $10,597,009
# 5   6   no         Techline              Health       2006  $13,898,119
# 6   7  yes          Cityace              Health       2010   $9,254,614
# 7   8   no   Kayelectronics              Health       2009   $9,451,943
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.fillna(2)
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                    2       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                    2       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011             2
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.fillna({"Industry":"none","Expenses":"no"})
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                 none       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                 none       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.fillna(method = "ffill")
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill          IT Services       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax               Health       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011  $14,001,180
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.fillna(method = "pad")
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill          IT Services       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax               Health       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011  $14,001,180
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.fillna(method = "bfill",axis = 1)
# Out:
#    ID Date             Name             Industry Inception            Revenue
# 0   1  yes          Lamtone          IT Services      2009       $11,757,018   \
# 1   2   no        Stripfind   Financial Services      2010       $12,329,371
# 2   3  yes  Canecorporation               Health      2012       $10,597,009
# 3   4   no         Mattouch          IT Services      2013       $14,026,934
# 4   5  yes        Techdrill                 2009      2009       $10,573,990
# 5   6   no         Techline               Health      2006       $13,898,119
# 6   7  yes          Cityace               Health      2010        $9,254,614
# 7   8   no   Kayelectronics               Health      2009        $9,451,943
# 8   9  yes          Ganzlax                 2011      2011       $14,001,180
# 9  10   no      Trantraxlax  Government Services      2011  5,635,276 Dollars
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...

# %%
df.fillna(0,limit = 2)
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                    0       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                    0       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011             0
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.fillna(12,inplace = True)
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                   12       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                   12       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011            12
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.replace("Health","Finance")
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation              Finance       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline              Finance       2006  $13,898,119
# 6   7  yes          Cityace              Finance       2010   $9,254,614
# 7   8   no   Kayelectronics              Finance       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.replace([1,2,3,4],[11,12,13,14])
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0  11  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1  12   no        Stripfind   Financial Services       2010  $12,329,371
# 2  13  yes  Canecorporation               Health       2012  $10,597,009
# 3  14   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.replace({"Industry":"Health","Profit":3005116},"none")
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation                 none       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline                 none       2006  $13,898,119
# 6   7  yes          Cityace                 none       2010   $9,254,614
# 7   8   no   Kayelectronics                 none       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.replace("[A-Za-z]",0,regex = True)
# Out:
#    ID  Date  Name  Industry  Inception       Revenue  Expenses    Profit
# 0   1     0     0       0.0       2009  $11,757,018        0.0   5274553  \
# 1   2     0     0       0.0       2010  $12,329,371        0.0  11412916
# 2   3     0     0       0.0       2012  $10,597,009        0.0   3005820
# 3   4     0     0       0.0       2013  $14,026,934        0.0   6597557
# 4   5     0     0       NaN       2009  $10,573,990        0.0   3138627
# 5   6     0     0       0.0       2006  $13,898,119        0.0   8427816
# 6   7     0     0       0.0       2010   $9,254,614        0.0   3005116
# 7   8     0     0       0.0       2009   $9,451,943        0.0   5573830
# 8   9     0     0       NaN       2011  $14,001,180        NaN  11901180
# 9  10     0     0       0.0       2011           NaN       0.0   5453060
#
#   Growth
# 0    30%
# 1    20%
# 2     7%
# 3    NaN
# 4     8%
# 5    23%
# 6     6%
# 7     4%
# 8    18%
# 9     7%

# %%
df.replace({"Industry":"[A-Za-z]"},0,regex = True)
# Out:
#    ID Date             Name  Industry  Inception       Revenue
# 0   1  yes          Lamtone       0.0       2009  $11,757,018   \
# 1   2   no        Stripfind       0.0       2010  $12,329,371
# 2   3  yes  Canecorporation       0.0       2012  $10,597,009
# 3   4   no         Mattouch       0.0       2013  $14,026,934
# 4   5  yes        Techdrill       NaN       2009  $10,573,990
# 5   6   no         Techline       0.0       2006  $13,898,119
# 6   7  yes          Cityace       0.0       2010   $9,254,614
# 7   8   no   Kayelectronics       0.0       2009   $9,451,943
# 8   9  yes          Ganzlax       NaN       2011  $14,001,180
# 9  10   no      Trantraxlax       0.0       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# 4  7,435,363 Dollars   3138627     8%
# 5  5,470,303 Dollars   8427816    23%
# ...

# %%
df = pd.read_csv("A:\\Data Science\\Fortune_10.csv")
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.replace("Health",method = "ffill")
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation   Financial Services       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline                  NaN       2006  $13,898,119
# 6   7  yes          Cityace                  NaN       2010   $9,254,614
# 7   8   no   Kayelectronics                  NaN       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.replace("Health",method = "bfill", limit = 2)
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation          IT Services       2012  $10,597,009
# 3   4   no         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace                  NaN       2010   $9,254,614
# 7   8   no   Kayelectronics                  NaN       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.replace("no",100,inplace = True)
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018   \
# 1   2  100        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4  100         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill                  NaN       2009  $10,573,990
# 5   6  100         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8  100   Kayelectronics               Health       2009   $9,451,943
# 8   9  yes          Ganzlax                  NaN       2011  $14,001,180
# 9  10  100      Trantraxlax  Government Services       2011           NaN
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df1 = pd.read_csv("A:\\Data Science\\student_10.csv")
df1
# Out:
#          Date  Student ID  Class  Study hrs  Percentage
# 0  01-07-2019      1001.0     10        2.0        50.0
# 1  02-07-2019      1002.0     10        NaN        80.0
# 2  03-07-2019         NaN     10        3.0        60.0
# 3  06-07-2019         NaN     11        0.0         NaN
# 4  07-07-2019      1005.0     11        4.0         NaN
# 5  08-07-2019         NaN     11       10.0         NaN
# 6  09-07-2019      1007.0     12        4.0        80.0
# 7  10-07-2019      1008.0     12        NaN        90.0
# 8  11-07-2019      1009.0     12        NaN        60.0
# 9  12-07-2019      1010.0     12        6.0        85.0

# %%
df1.interpolate(method = "linear")
# Out:
#          Date  Student ID  Class  Study hrs  Percentage
# 0  01-07-2019      1001.0     10   2.000000        50.0
# 1  02-07-2019      1002.0     10   2.500000        80.0
# 2  03-07-2019      1003.0     10   3.000000        60.0
# 3  06-07-2019      1004.0     11   0.000000        65.0
# 4  07-07-2019      1005.0     11   4.000000        70.0
# 5  08-07-2019      1006.0     11  10.000000        75.0
# 6  09-07-2019      1007.0     12   4.000000        80.0
# 7  10-07-2019      1008.0     12   4.666667        90.0
# 8  11-07-2019      1009.0     12   5.333333        60.0
# 9  12-07-2019      1010.0     12   6.000000        85.0

# %%
type(df1.Date[0])
# Out:
# str

# %%
df1 = pd.read_csv("A:\\Data Science\\student_10.csv",parse_dates = ["Date"], index_col = "Date")
df1
# Out:
#             Student ID  Class  Study hrs  Percentage
# Date
# 2019-01-07      1001.0     10        2.0        50.0
# 2019-02-07      1002.0     10        NaN        80.0
# 2019-03-07         NaN     10        3.0        60.0
# 2019-06-07         NaN     11        0.0         NaN
# 2019-07-07      1005.0     11        4.0         NaN
# 2019-08-07         NaN     11       10.0         NaN
# 2019-09-07      1007.0     12        4.0        80.0
# 2019-10-07      1008.0     12        NaN        90.0
# 2019-11-07      1009.0     12        NaN        60.0
# 2019-12-07      1010.0     12        6.0        85.0

# %%
df1.interpolate(method = "time")
# Out:
#             Student ID  Class  Study hrs  Percentage
# Date
# 2019-01-07     1001.00     10   2.000000   50.000000
# 2019-02-07     1002.00     10   2.525424   80.000000
# 2019-03-07     1002.56     10   3.000000   60.000000
# 2019-06-07     1004.40     11   0.000000   70.000000
# 2019-07-07     1005.00     11   4.000000   73.260870
# 2019-08-07     1006.00     11  10.000000   76.630435
# 2019-09-07     1007.00     12   4.000000   80.000000
# 2019-10-07     1008.00     12   4.659341   90.000000
# 2019-11-07     1009.00     12   5.340659   60.000000
# 2019-12-07     1010.00     12   6.000000   85.000000

# %%
df1.interpolate(method = "index")
# Out:
#             Student ID  Class  Study hrs  Percentage
# Date
# 2019-01-07     1001.00     10   2.000000   50.000000
# 2019-02-07     1002.00     10   2.525424   80.000000
# 2019-03-07     1002.56     10   3.000000   60.000000
# 2019-06-07     1004.40     11   0.000000   70.000000
# 2019-07-07     1005.00     11   4.000000   73.260870
# 2019-08-07     1006.00     11  10.000000   76.630435
# 2019-09-07     1007.00     12   4.000000   80.000000
# 2019-10-07     1008.00     12   4.659341   90.000000
# 2019-11-07     1009.00     12   5.340659   60.000000
# 2019-12-07     1010.00     12   6.000000   85.000000

# %%
df1 = pd.read_csv("A:\\Data Science\\student_10.csv", index_col = "Class")
df1
# Out:
#              Date  Student ID  Study hrs  Percentage
# Class
# 10     01-07-2019      1001.0        2.0        50.0
# 10     02-07-2019      1002.0        NaN        80.0
# 10     03-07-2019         NaN        3.0        60.0
# 11     06-07-2019         NaN        0.0         NaN
# 11     07-07-2019      1005.0        4.0         NaN
# 11     08-07-2019         NaN       10.0         NaN
# 12     09-07-2019      1007.0        4.0        80.0
# 12     10-07-2019      1008.0        NaN        90.0
# 12     11-07-2019      1009.0        NaN        60.0
# 12     12-07-2019      1010.0        6.0        85.0

# %%
df1.interpolate(method = "index")
# Out:
#              Date  Student ID  Study hrs  Percentage
# Class
# 10     01-07-2019      1001.0        2.0        50.0
# 10     02-07-2019      1002.0        3.0        80.0
# 10     03-07-2019      1002.0        3.0        60.0
# 11     06-07-2019      1005.0        0.0        70.0
# 11     07-07-2019      1005.0        4.0        70.0
# 11     08-07-2019      1005.0       10.0        70.0
# 12     09-07-2019      1007.0        4.0        80.0
# 12     10-07-2019      1008.0        6.0        90.0
# 12     11-07-2019      1009.0        6.0        60.0
# 12     12-07-2019      1010.0        6.0        85.0
